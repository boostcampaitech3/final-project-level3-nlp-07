# %%
import pandas as pd

df = pd.read_csv("../pre_nonner_total.csv")

# %%
df.sample(5)
# Out:
#                     업체명  맛  양 배달  \
# 241637      파리바게뜨-양재2호점  3  3  5
# 149695  이디야커피-미아꿈의숲해링턴점  5  5  5
# 94285           크로플각-본점  5  5  5
# 226310    엔제리너스-강남역사거리점  5  5  5
# 101479          설빙-노원역점  5  5  5
#
#                                                      주문메뉴     고객id  \
# 241637    꽈배기 도넛/1,돌돌말린 소시지 도넛/1,소보루빵/1,명가명품 우리벌꿀 카스텔라/1        손님
# 149695                      연유 콜드브루/1,허니 카라멜 브레드/1,프레즐/1        손님
# 94285    생크림 블루베리 크로플 세트（생크림 블루베리 크로플 ＋ 프렌치 크로플 ＋ 아이스아...  go\*\*님
# 226310   그린밀크티/2(HOT／ICE 선택(HOT),사이즈선택(S（12oz）),토핑추가(에...       손님
# 101479                            프리미엄생딸기설빙/1,인절미마카롱설빙/1        손님
#
#                                                    고객리뷰  \
# 241637                                    초고속 배달 감사합니다.
# 149695  빠른배달과 포장도 너무 꼼꼼하게 신경써서 잘 보내주셨어요\n손편지와 쿠키도 감사합니다
# 94285                          내일이 쉬는 날이라 오늘은 실컷 먹어야죠~~
# 226310                           깨끗하고 신속 정확! 변하지 않는 맛 !
# 101479                               맛있어용ㅎ 또 시켜먹을거 같아용ㅎ
#
#                                                      사장답글
# 241637       주문 받자마자 달려 갔습니다 ㅋㅋ 별점 ⭐⭐⭐⭐⭐을 위해 좀더 분발 하겠습니다~
# 149695          주문해주셔서 감사합니다 다음에도 더 맛있게 더 깨끗하게 준비해드리겠습니다!
# 94285   안녕하세요^^ #@상호명# 의 사장님(사장님 소리가 너무 듣고 싶어요~♥)입니다.\...
# 226310                 맛있게 드신후에 소중한 리뷰까지!!! 너무 감사드립니다❤️❤️
# 101479       감사합니다^^\n늘 맛있게 드리려 노력하고 있습니다.\n많은 이용 부탁드려요~~

# %% [markdown]
# # 많이 나오는 상호명 및 인스타 아이디 전처리

# %% [markdown]
# - 대상 상호명 : [요기요, 빠바, 파바, 파리바게트, 투썸, 이디야, etc.]
# - 대상 위치명 : [구로태평양IT점, 문래 6가점, c구로점, 청 량 리역사점, etc.]
# - 기관명 : [BR딜리버리, etc.]

# %%
import re

# %%
# 상호명 -> #@상호명# 마스킹
omitted_store = ['요기요', '빠바', '파바', '파리바게트', '투썸', '이디야', '테그 42', '메가커피', '망티', '스페이스핫도그', '그리너', '크로플덕', '요아정', '크로플각', '엉클도넛', '호구호구', '그린프루츠', '헤브번', '영스타', '딜리버거 & 카페', '가베 95카페', '샐러드 스탑', '퍼스트에이드', '날쌘카페', '사이드테이블', '아요성', 'sky31', '반달', '퀸즈', '1L카페', '카페 쉼', '온리 요거트', '밝을현', '행복한 날에', '노꼬', '배스킨']

print('-- ', df.iloc[10140]['사장답글'])
print('-- ', re.sub("|".join(omitted_store), "#@상호명#", df.iloc[10140]['사장답글']))

df["사장답글"] = df["사장답글"].str.replace("|".join(omitted_store), "#@상호명#")
# Out:
# --  감사합니다.
# 유기농 곡물과자는 어른들도 좋아합니다.
# 아이가 혹사라도 먹다가 목 막히지 않게 따뜻한 물과 같이 주세요. 따뜻한 물이 최고입니다. 그다음은 이디야~ ^^\*
# 감사합니다.
# --  감사합니다.
# 유기농 곡물과자는 어른들도 좋아합니다.
# 아이가 혹사라도 먹다가 목 막히지 않게 따뜻한 물과 같이 주세요. 따뜻한 물이 최고입니다. 그다음은 #@상호명#~ ^^\*
# 감사합니다.

# %%
# 위치 -> #@위치# 마스킹
omitted_loc = ['구로태평양IT점', '문래 6가점', 'c구로점', '신도림', 'LG 트윈타워점', '청 량 리역사점', 'PB한양대병원', '구로로제리움']

print('-- ', df.iloc[19430]['사장답글'])
print('-- ', re.sub("|".join(omitted_loc), "#@위치#", df.iloc[19430]['사장답글']))

df["사장답글"] = df["사장답글"].str.replace("|".join(omitted_loc), "#@위치#")
# Out:
# --  안녕하세요~#@상호명# c구로점입니다~!
# 식사에 불편을 드려서 죄송합니다.
# 항상 정성을 다하여 고객님께서 만족하실수 있도록 노력하는 #@상호명# c구로점이 되겠습니다. 감사합니다:)
# --  안녕하세요~#@상호명# #@위치#입니다~!
# 식사에 불편을 드려서 죄송합니다.
# 항상 정성을 다하여 고객님께서 만족하실수 있도록 노력하는 #@상호명# #@위치#이 되겠습니다. 감사합니다:)

# %%
# 기관 -> #@기관# 마스킹
omitted_org = ['BR딜리버리', '도봉구 복지재단']

print('-- ', df.iloc[94560]['사장답글'])
print('-- ', re.sub("|".join(omitted_org), "#@기관#", df.iloc[94560]['사장답글']))

df["사장답글"] = df["사장답글"].str.replace("|".join(omitted_org), "#@기관#")
# Out:
# --  [누적금액 : 919000원
# .
# [21.12.13. 부터 리뷰1건당 도봉구 복지재단에 나눔합니다] 여러분께 받은 많은 사랑
# 어떻게 돌려드려야하나 고민하다 특정대상보다는
# 어려운 이웃을위해 도움이되어야겠다고 생각했습니다. 한 건당 기부금을 차곡차곡모아서
# 매달 말 전액 기부 후 SNS를통해 인증하도록 하겠습니다. 사랑받은만큼 돌려드릴 수 있도록 노력하겠습니다.
# 감사합니다.
# -------------------------------------
# --  [누적금액 : 919000원
# .
# [21.12.13. 부터 리뷰1건당 #@기관#에 나눔합니다] 여러분께 받은 많은 사랑
# 어떻게 돌려드려야하나 고민하다 특정대상보다는
# 어려운 이웃을위해 도움이되어야겠다고 생각했습니다. 한 건당 기부금을 차곡차곡모아서
# 매달 말 전액 기부 후 SNS를통해 인증하도록 하겠습니다. 사랑받은만큼 돌려드릴 수 있도록 노력하겠습니다.
# 감사합니다.
# -------------------------------------

# %%
# 인스타 -> #@전화번호# 마스킹
print('-- ', df.iloc[30944]['사장답글'])
print('-- ', re.sub("\@[a-zA-Z0-9_]+", "#@전화번호#", df.iloc[30944]['사장답글']))

df["사장답글"] = df["사장답글"].str.replace("\@[a-zA-Z0-9_]+", "#@전화번호#")
# Out:
# --  아아아 너무 죄송해요 ㅠㅠ 다행히 리뷰를 빨리 써주셔서 확인되었습니다. 다음주문시에 꼭 2개 갈 수 있도록 할게요!!! 실망하셨을텐데 좋은평 해주셔서 너무 감사드려요 ㅠㅠ 현재 딸기케이크는 딸기프레지에 딸기타르트 멜팅 스트로베리 딸기생크림케이크 이렇게 네 종류가 있는데요 딸기생크림케이크는 배달에 어려움이 있어보여 앱에는 추가하지 못했어요 ㅠ... 모습이 궁금하시면 ( #@고객이름# 인스타 @cakepop_star9 ) ( 제 인스타 @cakepop2019 )에서 확인하실 수 있구요! 궁금하신게 있으면 언제든 dm주세요!!!
# --  아아아 너무 죄송해요 ㅠㅠ 다행히 리뷰를 빨리 써주셔서 확인되었습니다. 다음주문시에 꼭 2개 갈 수 있도록 할게요!!! 실망하셨을텐데 좋은평 해주셔서 너무 감사드려요 ㅠㅠ 현재 딸기케이크는 딸기프레지에 딸기타르트 멜팅 스트로베리 딸기생크림케이크 이렇게 네 종류가 있는데요 딸기생크림케이크는 배달에 어려움이 있어보여 앱에는 추가하지 못했어요 ㅠ... 모습이 궁금하시면 ( #@고객이름# 인스타 #@전화번호# ) ( 제 인스타 #@전화번호# )에서 확인하실 수 있구요! 궁금하신게 있으면 언제든 dm주세요!!!

# %%
# 전화번호 -> #@전화번호# 마스킹
print('-- ', df.iloc[204910]['사장답글'])
print('-- ', re.sub("(2\.[\w\.]+)|(010-[\w-]+)", "#@전화번호#", df.iloc[204910]['사장답글']))

df["사장답글"] = df["사장답글"].str.replace("(2\.[\w\.]+)|(010-[\w-]+)", "#@전화번호#")
# Out:
# --  고객님 정말 귀한 기념일을 즐겁게 보내지 못하게 해드려 죄송합니다ㅠ너무 죄송하고 일단 이 번호 연락주시면 제가 계좌로 환불조치 취해드리겠습니다ㅠ너무 죄송합니다ㅠ 010-삼635-공181
# --  고객님 정말 귀한 기념일을 즐겁게 보내지 못하게 해드려 죄송합니다ㅠ너무 죄송하고 일단 이 번호 연락주시면 제가 계좌로 환불조치 취해드리겠습니다ㅠ너무 죄송합니다ㅠ #@전화번호#

# %% [markdown]
# # 고객 주문위치, 가게주소 마스킹 처리

# %% [markdown]
# - 데이터 양이 너무 많고 & NER 연산 시간이 오래 걸리기 때문에, 특정 상호만 마스킹

# %%
len(df['업체명'].unique())
# Out:
# 3316

# %%
company_dict = {x:i for i, x in enumerate(df['업체명'].unique())}
company_gen= (x for x in df['업체명'].unique())
company_gen
# Out:
# <generator object <genexpr> at 0x7f7fe0351eb0>

# %%
company = next(company_gen)
specific_df = df[df['업체명'] == company]

print('i:', company_dict[company])
list(specific_df["사장답글"])[:10]
# Out:
# i: 348
# ['🐭 사랑합니다!',
#  '🐭 : 감사합니다!',
#  '🐹 와 대장님! 사진 너무 이쁘게 찍어주셨어요!!!\n🐭 오오~ 손님 네일이 너무 예뻐서 우리 마카롱이 엄청 살아났어!! 어떡해어떡해\n🐹 대장님! 카페주문도 처음하셨다는데요??\n🐭 감동이야ㅠㅠㅠ 2호야 우리 좀 울자ㅠㅠ\n🐭🐹 찍찍😭😭😭😭😭😭 만족해주셔서 감사합니다😭😭😭😭😭',
#  '🐭 ㅠㅠ 휘낭시에가 조기품절되어서... 못드린게 너무너무 아쉽네요ㅠㅠ\n🐹 그러게 #@고객이름# 제가 많이 만들어놓자고 했자나요!! 훌륭하고 멋진 직원의 조언은 쥐구멍으로 들으시더니 이게 뭐예요!!\n🐭 흐앙 너무 그러지마ㅠㅠㅠㅠ\n🐹 어?... #@고객이름# 오늘은 뭐라 안하시고... 우시다니... #@고객이름#..ㅠ 왜그러세요ㅠ 기죽지말고! 뚝! 하고 힘내세요! 그럼 #@고객이름# 혼자 시간좀 보내셔야되니깐 전 퇴근하겠습니다!\n🐭 일루와! 오늘도 야!근!\n🐹 찍😭',
#  '🐹 #@고객이름# #@고객이름#께서 알짜배기만 시키셨어요!!\n🐭 상큼상큼 요거트에 달달달 청포도 복숭아 잼이라니!!! 끝이아니라 오레오크림치즈까지... 풍년이로구나!!\n🐹 대..#@고객이름#?? 쫌 오버하는것 같은데요??\n🐭 풍악을 울려라~ 덩기덕 쿵 더러러러 쿵 기덕 쿵 더러러러\n🐹 #@고객이름# 죄송합니다... #@고객이름#이 너무 신나셨나본데요... 맛있어 해주셔서 감사합니다! 찍',
#  '🐹 #@고객이름#! 화이트데이날이고 남자분이셨는데!! 좋은일이 있었겠죠??!!!\n🐭 어허 2호! 그런건 찍찍대는게 아니에요~ 본인이나 파티셰로써 직접 맛있는 디저트를 만들어서 여친한테 주세요~\n🐹 #@고객이름#... 여친이 있냐고 먼저 물어봐주시는게...\n🐭 ???\n🐹 😭\n🐭 후... 마치고 삼겹살에 소주한잔 하러가자...\n🐹 네?? 대... #@고객이름#도...??\n🐭 😭',
#  '🐭 아휴... 우리 구로구민들 홧찍입니다ㅠ 답답했던 마음 쥐구멍으로 인해 조금이라도 풀리셨다니 너무 다행이고 감사한 마음이네요...!\n🐹 #@고객이름#... 매일 야근하는 저의 답답한 마음도 조금만 풀어주시면...\n🐭 사랑해😚\n🐹 싫어... 너무싫어ㅠㅠㅠㅠ',
#  '🐭 흐아.. 얼음이 쪼오금 녹아버렸네요..ㅠ 피크시간대라 차가 조금 막혔나보네요ㅠ 더욱더 신경쓰겠습니다!!\n🐹 #@고객이름#!! 그래도 처음시켜드시는데 마카롱이랑 커피도 맛있어하셨고 아주 만족하신거 같으신데요??\n🐭 2호!! 잘된점보다! 잘못된점을 더 봐야되고!! 개선하도록 노력해야지!!! 자~ 야근이다!!!\n🐹 찍😱',
#  '🐹 #@고객이름#! 역시 딸기라떼❤ 빨리 재료 많이많이 시켜야 될것 같아요!!!\n🐭 으흠... 뭔가 석연찮은 기분이 들긴하지만... 덮어두기로 하지...\n🐹 찍? 에이 무슨 아녀아녀유~ 저 그렇게 많이 안먹어유~\n🐭 그래 믿어줄게. 빨리 휘낭시에 설명 한번 드려~\n🐹 휘..휘낭시에요..? 엄... 태운버터를 이용해서... 버터의 풍미가 풍부한...프랑스대표...구움과자...\n🐭 후... 공부하러가자\n🐹 퇴근하겠습니다!',
#  '🐭 저희꼬끄가 프렌치머랭으로 만들기때문에 쫀득쫀득해요~!! 쥐구멍 베스트 멤버 순우유 레드벨벳을 시키셨네요 ㅎㅎ 오레오도 뒤지지않기 때문에 같이 붙여드렸어요 ㅎㅎ\n🐹 #@고객이름#! 바닐라도 베스트 멤버아니예요??\n🐭 2호!! 그런식으로 어? 홍보하는것같이 어? 그러면 어? 아주 이뻐해줄거야😘\n🐹 으악!!!! 찍🤮']

# %%
company = next(company_gen)
specific_df = df[df['업체명'] == company]

print('i:', company_dict[company])
list(specific_df["사장답글"])[:10]
# Out:
# i: 425
# ['고객님 안녕하세요😚\n고객님의 소중한 주문과 리뷰 정말 감사합니다. 고객님 맛있게 드셨나요?? 주기적으로 #@상호명#을 찾아주시는 고객님 최고 ‧˚₊\\*̥(\\* ⁰̷̴͈꒨⁰̷̴͈)‧˚₊\\*̥ 이번주 일요일까지 #@상호명# 행사 하오니 또또또 이용해주세요 !! 항상 고객님께서 만족하실 수 있는 저희 #@상호명# 신림 양지병원점을 또 찾아주세요 ❤️',
#  '고객님 안녕하세요 😚 고객님의 소중한 주문과 리뷰 정말 감사합니다. 고객님 맛있게 드셨나요?? 진짜 베이글이 너무~~ 맛있긴 합니다ㅠㅠ 치즈인 베이글에 크림치즈 한번만 발라서 드셔주세여 (๑˙ϖ˙๑ )\u202c 최고예요 !!!!!👍🏻 이번주 일요일까지 #@상호명# 행사하오니 또 이용해주실꺼죠? 앞으로도 고객님의 기분 좋은 경험을 만들기 위해 더욱 노력하는 #@상호명#이 되겠습니다 ❤️',
#  '고객님 안녕하세요😚\n고객님의 소중한 주문과 리뷰 정말 감사합니다. 고객님 맛있게 드셨나요?? 따듯하게 빨리 배달이 되었다니 저 또한 기분이 좋네요오옹 .o♡₊˚ ପ⸝⸝・o・⸝⸝ଓ ˚｡이번주 일요일까지 #@상호명# 행사 하오니 또또또 이용해주세요 !! 항상 고객님께서 만족하실 수 있는 저희 #@상호명# 신림 양지병원점을 또 찾아주세요 ❤️',
#  '고객님 안녕하세요 😚 고객님의 소중한 주문과 리뷰 정말 감사합니다. 고객님 맛있게 드셨나요?? 고객님 정말 죄송하지만 영수증을 보았을때는 플라스틱컵으로 주문해주신게 맞네요 ㅠ.ㅠ다음번에는 컵 선택하실때 캔으로 꼭 선택해주시면 캔으로 안전하게 배달할 수 있도록 하겠습니다 (\u3000-̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥᷄ ω -̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥̥᷅ ) 이번주 일요일까지 #@상호명# 행사하오니 이용해주실꺼죠? 앞으로도 고객님의 기분 좋은 경험을 만들기 위해 더욱 노력하는 #@상호명#이 되겠습니다❤️',
#  '고객님 안녕하세요 😚 고객님의 소중한 주문과 리뷰 정말 감사합니다.\n고객님 맛있게 드셨나요?? 맛있게 잘 드셔주셔서 너무너무 감사합니다 ₍₍ (ง ˘ω˘ )ว ⁾⁾ 이번주 일요일까지 #@상호명# 행사합니다 ~~ 많은 이용부탁드립니당!! 항상 고객님께서 만족하실 수 있는 저희 #@상호명# 신림 양지병원점을 또 찾아주세요 ❤️',
#  '안녕하세요 고객님 😆\n고객님의 소중한 리뷰 감사드립니다 ❤\n맛있게드셨다니 뿌듯하네용🤭\n다음에도 맛있게 드실수있도록\n정성스럽게 준비해서 보내드릴게요😄\n앞으로도 저희 #@상호명#\n이용부탁드립니다😘',
#  '안녕하세요 고객님 😆 앗..리뷰 달아주셔서 정말 감사합니다😊😊😊\n이번주내내 행사진행하고있으니\n저렴하게 앳홈제품 득템하시길 바랍니다😘\n리뷰주시면 여러가지 서비스드리고있으니\n요청사항에 기재부탁드립니당ㅎㅎ\n다음 주문도 저희 #@상호명#과\n함께 해주세요😄',
#  '안녕하세요 고객님 😆\n고객님의 소중한 리뷰 감사드립니다 ❤ 주문하신것보니 초코를 사랑하는\n고객님이시군요?😏\n초코를 좋아하신다면 다음에는 초코구움도넛도\n드셔보세용 구움도넛이 가성비는 최고👍👍\n이번주 행사진행하고있으니\n이번기회에 저렴하게 드셔보시길 바랍니당🤭\n다음 주문도 저희 #@상호명#과\n함께해주세요🥰',
#  '안녕하세요 고객님 😆\n고객님의 소중한 리뷰 감사드립니다 ❤\n앗 저희 음료도 맛있게 드신거겠죠?\U0001f972\n다음 주문에도 맛있게 드실수있도록\n노력하겠습니다😙\n앞으로도 저희 #@상호명# 이용부탁드립니다 ❤',
#  '안녕하세요 고객님 😆\n고객님의 소중한 리뷰 감사드립니다 ❤ 저희매장만 애용해 주신다니\n너무너무 감사합니다😍😍😍\n앞으로도 만족하실수있도록 더욱\n노력하는 #@상호명#이 되겠습니다😉\n계속 저희 #@상호명# 애용해주세용🥰']

# %%
df.sample(2)
# Out:
#                 업체명  맛  양 배달  \
# 202056   뚜레쥬르-양천캐슬점  5  5  4
# 160344  배스킨라빈스-이태원점  5  5  5
#
#                                                      주문메뉴     고객id  \
# 202056                                          빵긋랜덤박스/1   se\*\*님
# 160344   쿼터/1(아이스크림 선택（쿼터）(엄마는 외계인,바람과 함께 사라지다,슈팅스타,뉴욕...       손님
#
#                                                      고객리뷰  \
# 202056  배달은 조금 늦었습니다만 구성이 진짜 알차고 빵들이 하나하나 다 너무 맛있어서 놀랐...
# 160344        손편지도 써 주시고 양도 푸짐하고 사장님 서비스가 최고네요\n감사합니다~~^^
#
#                                                      사장답글
# 202056  안녕하세요 고객님! 랜덤빵 주문해주셔서 감사드리고 빵맛에 엄격하심에도 불구(^^) ...
# 160344  #@고객이름#\n#@상호명# 직영점으로 운영중인 #@상호명#입니다.\n코로나19로 ...

# %%
df.to_csv("prev2_final_total_data.csv", encoding="utf-8", index=False)
